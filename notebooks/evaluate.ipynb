# %%
# !cd ..; pwd
# Out:
# /dis/soc/HELGE

# %% [markdown]
# # APELID

# %% [markdown]
# ## CSE-CIC-IDS2018

# %% [markdown]
# ### Individual models

# %%
# !cd ..; python cli/apelid/5_training/model_evaluation.py -r cic2018 --mode model --models xgb catb gbm bagging dnn
# Out:
# 2025-12-11 22:34:28 - __main__ - INFO - [+] Loading test data: data/cic2018_test_random_sample_clean_merged.csv
# 2025-12-11 22:34:28 - __main__ - INFO - [+] Test data shape: (51129, 64)
# 2025-12-11 22:34:28 - preprocessing.cic2018_preprocessor - INFO - [+] CIC-2018 encoders loaded from encoders/cic2018
# 2025-12-11 22:34:28 - __main__ - INFO - [+] Evaluating 5 models: ['xgb', 'catb', 'gbm', 'bagging', 'dnn']
# 2025-12-11 22:34:35 - __main__ - INFO - [+] Combined results saved to: reports/cic2018/evaluation/cic2018_all_models_metrics.json
# 2025-12-11 22:34:35 - __main__ - INFO - [+] Evaluation Summary:
# 2025-12-11 22:34:35 - __main__ - INFO -   xgb: Accuracy=0.9595, F1=0.9595, Precision=0.9595, Recall=0.9595
# 2025-12-11 22:34:35 - __main__ - INFO -   catb: Accuracy=0.9590, F1=0.9590, Precision=0.9590, Recall=0.9590
# 2025-12-11 22:34:35 - __main__ - INFO -   gbm: Accuracy=0.9591, F1=0.9591, Precision=0.9591, Recall=0.9591
# ...

# %% [markdown]
# ### Ensemble: APELID

# %%
# !cd ..; python cli/apelid/5_training/parallel_ensemble.py -r cic2018 --save-mt --save-cm
# Out:
# 2025-12-11 22:34:40 - __main__ - INFO - [+] Loading test data: data/cic2018_test_random_sample_clean_merged.csv
# 2025-12-11 22:34:40 - __main__ - INFO - [+] Test data shape: (51129, 64)
# 2025-12-11 22:34:40 - preprocessing.cic2018_preprocessor - INFO - [+] CIC-2018 encoders loaded from encoders/cic2018
# 2025-12-11 22:34:40 - helpers.ensemble_helper - WARNING - [!] Model not found: resources/CIC-2018/models/cic2018_histgbm.pkl
# 2025-12-11 22:34:40 - __main__ - INFO - [+] Parallel ensemble with 5 models: ['xgb', 'dnn', 'catb', 'bagging', 'gbm']
# 2025-12-11 22:34:41 - __main__ - INFO - [+] Parallel ensemble prediction with 5 models (max_workers=4, batch_size=-1)
# 2025-12-11 22:34:44 - helpers.ensemble_helper - INFO - [+] Combining predictions from 5 models
# 2025-12-11 22:34:44 - helpers.ensemble_helper - INFO - [+] Added catb with weight 0.20 (shape: (51129, 12))
# 2025-12-11 22:34:44 - helpers.ensemble_helper - INFO - [+] Added xgb with weight 0.30 (shape: (51129, 12))
# ...

# %% [markdown]
# ## NSLKDD

# %% [markdown]
# ### Individual models

# %%
# !cd ..; python cli/apelid/5_training/model_evaluation.py -r nslkdd --mode model --models xgb catb gbm bagging dnn
# Out:
# 2025-12-11 22:34:50 - __main__ - INFO - [+] Loading test data: data/nslkdd_test_random_sample_clean_merged.csv
# 2025-12-11 22:34:50 - __main__ - INFO - [+] Test data shape: (17336, 42)
# 2025-12-11 22:34:50 - preprocessing.nslkdd_preprocessor - INFO - [+] Encoders loaded from encoders/nslkdd
# 2025-12-11 22:34:50 - __main__ - INFO - [+] Evaluating 5 models: ['xgb', 'catb', 'gbm', 'bagging', 'dnn']
# 2025-12-11 22:34:54 - __main__ - INFO - [+] Combined results saved to: reports/nslkdd/evaluation/nslkdd_all_models_metrics.json
# 2025-12-11 22:34:54 - __main__ - INFO - [+] Evaluation Summary:
# 2025-12-11 22:34:54 - __main__ - INFO -   xgb: Accuracy=0.9950, F1=0.9950, Precision=0.9950, Recall=0.9950
# 2025-12-11 22:34:54 - __main__ - INFO -   catb: Accuracy=0.9938, F1=0.9938, Precision=0.9938, Recall=0.9938
# 2025-12-11 22:34:54 - __main__ - INFO -   gbm: Accuracy=0.9928, F1=0.9928, Precision=0.9928, Recall=0.9928
# ...

# %% [markdown]
# ### Ensemble: APELID

# %%
# !cd ..; python cli/apelid/5_training/sequential_ensemble.py -r nslkdd --save-mt --save-cm
# Out:
# 2025-12-11 22:34:58 - __main__ - INFO - [+] Loading test data: data/nslkdd_test_random_sample_clean_merged.csv
# 2025-12-11 22:34:58 - __main__ - INFO - [+] Test data shape: (17336, 42)
# 2025-12-11 22:34:58 - preprocessing.nslkdd_preprocessor - INFO - [+] Encoders loaded from encoders/nslkdd
# 2025-12-11 22:34:58 - __main__ - INFO - [+] using_histgbm is OFF: disabled 'histgbm', using 'gbm' if present
# 2025-12-11 22:34:58 - __main__ - INFO - [+] Sequential ensemble with 5 models: ['xgb', 'dnn', 'catb', 'bagging', 'gbm']
# 2025-12-11 22:34:58 - __main__ - INFO - [+] Sequential ensemble prediction with 5 models (batch_size=-1)
# 2025-12-11 22:35:01 - helpers.ensemble_helper - INFO - [+] Combining predictions from 5 models
# 2025-12-11 22:35:01 - helpers.ensemble_helper - INFO - [+] Added xgb with weight 0.30 (shape: (17336, 5))
# 2025-12-11 22:35:01 - helpers.ensemble_helper - INFO - [+] Added dnn with weight 0.10 (shape: (17336, 5))
# ...

# %% [markdown]
# # Attack evaluations

# %% [markdown]
# ## CSE-CIC-IDS2018

# %% [markdown]
# ### Individual models: No defenses

# %%
# !echo "-----Evaluating individual models (no defense)-----"
# !cd ..; python cli/apelid/8_attack_evaluation/classifier_evaluate_adv.py -r cic2018 --model xgb catb gbm bagging dnn --attack zoo hsja fgsm jsma pgd deepfool cw
# Out:
# -----Evaluating individual models (no defense)-----
# 2025-12-11 22:35:04 - preprocessing.cic2018_preprocessor - INFO - [+] CIC-2018 encoders loaded from encoders/cic2018
# 2025-12-11 22:35:55 - __main__ - INFO -
# +-------------+---------------------+---------------------+---------------------+---------------------+---------------------+
# | Attack/File |         xgb         |         catb        |         gbm         |       bagging       |         dnn         |
# +-------------+---------------------+---------------------+---------------------+---------------------+---------------------+
# |   original  |   95.95% (asr:--)   |   95.90% (asr:--)   |   95.91% (asr:--)   |   95.91% (asr:--)   |   93.39% (asr:--)   |
# |      cw     | 69.97% (asr:27.61%) | 47.36% (asr:51.18%) | 71.90% (asr:25.37%) | 52.20% (asr:45.84%) | 32.47% (asr:65.23%) |
# |   deepfool  | 50.04% (asr:49.35%) | 13.02% (asr:88.40%) | 17.74% (asr:82.58%) | 23.77% (asr:76.19%) |  1.90% (asr:99.62%) |
# ...

# %% [markdown]
# ### Individual models: Ablation study

# %%
# !echo "-----Evaluating individual models (feature-squeezing-applied)-----"
# !cd ..; python cli/apelid/8_attack_evaluation/classifier_evaluate_adv.py -r cic2018 -m xgb catb gbm bagging dnn -a zoo hsja fgsm jsma pgd deepfool cw --fs-enable --fs-config xgb:6 catb:2 gbm:2 bagging:2 dnn:2
# !echo "-----Evaluating individual models (adversarial-robusted-only)-----"
# !cd ..; python cli/apelid/8_attack_evaluation/classifier_evaluate_adv.py -r cic2018 -m xgb catb gbm bagging dnn -a zoo hsja fgsm jsma pgd deepfool cw --using-robust
# Out:
# -----Evaluating individual models (feature-squeezing-applied)-----
# 2025-12-11 22:35:58 - preprocessing.cic2018_preprocessor - INFO - [+] CIC-2018 encoders loaded from encoders/cic2018
# 2025-12-11 22:36:48 - __main__ - INFO -
# +-------------+---------------------+---------------------+---------------------+---------------------+---------------------+
# | Attack/File |         xgb         |         catb        |         gbm         |       bagging       |         dnn         |
# +-------------+---------------------+---------------------+---------------------+---------------------+---------------------+
# |   original  |   95.94% (asr:--)   |   95.89% (asr:--)   |   95.35% (asr:--)   |   86.49% (asr:--)   |   93.38% (asr:--)   |
# |      cw     | 69.96% (asr:27.61%) | 47.37% (asr:51.18%) | 71.90% (asr:25.00%) | 52.09% (asr:42.05%) | 32.47% (asr:65.23%) |
# |   deepfool  | 50.04% (asr:49.35%) | 13.03% (asr:88.38%) | 17.74% (asr:82.54%) | 23.77% (asr:73.75%) |  1.89% (asr:99.62%) |
# ...

# %% [markdown]
# ### Individual models: Full Defenses (APELID-ATH: adversarial robusting + feature squeezing)

# %%
# !echo "-----Evaluating individual models (APELID-ATH)-----"
# !cd ..; python cli/apelid/8_attack_evaluation/classifier_evaluate_adv.py -r cic2018 -m xgb catb gbm bagging dnn -a zoo hsja fgsm jsma pgd deepfool cw --using-robust --fs-enable --fs-config xgb:6 catb:2 gbm:2 bagging:2 dnn:2
# Out:
# -----Evaluating individual models (APELID-ATH)-----
# 2025-12-11 22:37:47 - preprocessing.cic2018_preprocessor - INFO - [+] CIC-2018 encoders loaded from encoders/cic2018
# 2025-12-11 22:38:38 - __main__ - INFO -
# +-------------+---------------------+--------------------+--------------------+--------------------+--------------------+
# | Attack/File |         xgb         |        catb        |        gbm         |      bagging       |        dnn         |
# +-------------+---------------------+--------------------+--------------------+--------------------+--------------------+
# |   original  |   95.97% (asr:--)   |  95.77% (asr:--)   |  95.84% (asr:--)   |  95.80% (asr:--)   |  93.04% (asr:--)   |
# |      cw     | 86.36% (asr:10.37%) | 95.26% (asr:0.97%) | 89.64% (asr:7.00%) | 95.17% (asr:1.33%) | 93.04% (asr:0.00%) |
# |   deepfool  |  94.65% (asr:2.71%) | 94.56% (asr:2.51%) | 93.04% (asr:3.83%) | 91.98% (asr:5.80%) | 90.86% (asr:3.78%) |
# ...

# %% [markdown]
# ### Ensemble model (APELID): No defenses

# %%
# !echo "-----Evaluating APELID (no defense)-----"
# !cd ..; python cli/apelid/8_attack_evaluation/classifier_parallel_ens_eval.py -a zoo hsja fgsm jsma pgd deepfool cw -r cic2018
# Out:
# -----Evaluating APELID (no defense)-----
# 2025-12-11 22:38:43 - __main__ - INFO - [+] Loading plain test data: data/cic2018_test_random_sample_clean_merged.csv
# 2025-12-11 22:38:44 - preprocessing.cic2018_preprocessor - INFO - [+] CIC-2018 encoders loaded from encoders/cic2018
# 2025-12-11 22:38:44 - __main__ - INFO - [+] Ensemble models: ['xgb', 'dnn', 'catb', 'bagging', 'gbm']
# 2025-12-11 22:39:26 - __main__ - INFO -
# +-------------+--------+--------+-----------+--------+--------+
# | Attack/File |  Acc   |   F1   | Precision | Recall |  ASR   |
# +-------------+--------+--------+-----------+--------+--------+
# |   original  | 96.01% | 96.01% |   96.01%  | 96.01% |   --   |
# |     zoo     | 96.02% | 96.02% |   96.02%  | 96.02% | 0.01%  |
# |     hsja    | 32.20% | 32.20% |   32.20%  | 32.20% | 68.98% |
# |     fgsm    | 96.04% | 96.04% |   96.04%  | 96.04% | 0.13%  |
# |     jsma    | 96.26% | 96.26% |   96.26%  | 96.26% | 0.07%  |
# ...

# %% [markdown]
# ### Ensemble model (APELID): Ablation Study

# %%
# !echo "-----Evaluating APELID (feature-squeezing-applied: APELID-FS)-----"
# !cd ..; python cli/apelid/8_attack_evaluation/classifier_parallel_ens_eval.py -a zoo hsja fgsm jsma pgd deepfool cw -r cic2018 --fs-enable --fs-config xgb:6 catb:2 gbm:2 bagging:2 dnn:2
# !echo "-----Evaluating APELID (adversarial-robusted-only: APELID-HT)-----"
# !cd ..; python cli/apelid/8_attack_evaluation/classifier_parallel_ens_eval.py -a zoo hsja fgsm jsma pgd deepfool cw -r cic2018 --using-robust
# !echo "-----Evaluating APELID (APELID-isolated-robust: APELID-IR)-----"
# !cd ..; python cli/apelid/8_attack_evaluation/classifier_parallel_ens_eval.py -a zoo hsja fgsm jsma pgd deepfool cw -r cic2018 --using-isolated-robust --fs-enable --fs-config xgb:6 catb:2 gbm:2 bagging:2 dnn:2
# Out:
# -----Evaluating APELID (feature-squeezing-applied: APELID-FS)-----
# 2025-12-11 22:39:31 - __main__ - INFO - [+] Loading plain test data: data/cic2018_test_random_sample_clean_merged.csv
# 2025-12-11 22:39:32 - preprocessing.cic2018_preprocessor - INFO - [+] CIC-2018 encoders loaded from encoders/cic2018
# 2025-12-11 22:39:32 - __main__ - INFO - [+] Ensemble models: ['xgb', 'dnn', 'catb', 'bagging', 'gbm']
# 2025-12-11 22:40:14 - __main__ - INFO -
# +-------------+--------+--------+-----------+--------+--------+
# | Attack/File |  Acc   |   F1   | Precision | Recall |  ASR   |
# +-------------+--------+--------+-----------+--------+--------+
# |   original  | 96.01% | 96.01% |   96.01%  | 96.01% |   --   |
# |     zoo     | 95.99% | 95.99% |   95.99%  | 95.99% | 0.06%  |
# |     hsja    | 33.46% | 33.46% |   33.46%  | 33.46% | 67.64% |
# |     fgsm    | 96.05% | 96.05% |   96.05%  | 96.05% | 0.11%  |
# |     jsma    | 96.23% | 96.23% |   96.23%  | 96.23% | 0.11%  |
# ...

# %% [markdown]
# ### Ensemble model (APELID): Full Defenses (APELID-ATH: adversarial robusting + feature squeezing)

# %%
# !echo "-----Evaluating APELID (APELID-ATH)-----"
# !cd ..; python cli/apelid/8_attack_evaluation/classifier_parallel_ens_eval.py -a zoo hsja fgsm jsma pgd deepfool cw -r cic2018 --using-robust --fs-enable --fs-config xgb:6 catb:2 gbm:2 bagging:2 dnn:2
# Out:
# -----Evaluating APELID (APELID-ATH)-----
# 2025-12-11 22:41:55 - __main__ - INFO - [+] Loading plain test data: data/cic2018_test_random_sample_clean_merged.csv
# 2025-12-11 22:41:55 - preprocessing.cic2018_preprocessor - INFO - [+] CIC-2018 encoders loaded from encoders/cic2018
# 2025-12-11 22:41:55 - __main__ - INFO - [+] Ensemble models: ['xgb', 'dnn', 'catb', 'bagging', 'gbm']
# 2025-12-11 22:42:37 - __main__ - INFO -
# +-------------+--------+--------+-----------+--------+-------+
# | Attack/File |  Acc   |   F1   | Precision | Recall |  ASR  |
# +-------------+--------+--------+-----------+--------+-------+
# |   original  | 95.95% | 95.95% |   95.95%  | 95.95% |   --  |
# |     zoo     | 95.94% | 95.94% |   95.94%  | 95.94% | 0.03% |
# |     hsja    | 95.79% | 95.79% |   95.79%  | 95.79% | 0.59% |
# |     fgsm    | 96.93% | 96.93% |   96.93%  | 96.93% | 0.02% |
# |     jsma    | 97.33% | 97.33% |   97.33%  | 97.33% | 0.07% |
# ...

# %% [markdown]
# ## NSLKDD

# %% [markdown]
# ### Individual models: No defenses

# %%
# !echo "-----Evaluating individual models (no defense)-----"
# !cd ..; python cli/apelid/8_attack_evaluation/classifier_evaluate_adv.py -r nslkdd --model xgb catb gbm bagging dnn --attack zoo hsja fgsm jsma pgd deepfool cw
# Out:
# -----Evaluating individual models (no defense)-----
# 2025-12-11 22:42:40 - preprocessing.nslkdd_preprocessor - INFO - [+] Encoders loaded from encoders/nslkdd
# 2025-12-11 22:42:54 - __main__ - INFO -
# +-------------+---------------------+---------------------+---------------------+---------------------+---------------------+
# | Attack/File |         xgb         |         catb        |         gbm         |       bagging       |         dnn         |
# +-------------+---------------------+---------------------+---------------------+---------------------+---------------------+
# |   original  |   99.50% (asr:--)   |   99.38% (asr:--)   |   99.28% (asr:--)   |   99.29% (asr:--)   |   98.57% (asr:--)   |
# |      cw     | 80.57% (asr:19.04%) | 82.10% (asr:17.38%) | 85.42% (asr:13.97%) | 82.20% (asr:17.25%) | 83.40% (asr:15.39%) |
# |   deepfool  | 30.76% (asr:69.25%) | 24.19% (asr:75.87%) | 26.49% (asr:73.58%) | 19.88% (asr:80.17%) |  0.87% (asr:99.89%) |
# ...

# %% [markdown]
# ### Individual models: Ablation study

# %%
# !echo "-----Evaluating individual models (feature-squeezing-applied)-----"
# !cd ..; python cli/apelid/8_attack_evaluation/classifier_evaluate_adv.py -r nslkdd -m xgb catb gbm bagging dnn -a zoo hsja fgsm jsma pgd deepfool cw --fs-enable --fs-config xgb:6 catb:8 gbm:8 bagging:8 dnn:2
# !echo "-----Evaluating individual models (adversarial-robusted-only)-----"
# !cd ..; python cli/apelid/8_attack_evaluation/classifier_evaluate_adv.py -r nslkdd -m xgb catb gbm bagging dnn -a zoo hsja fgsm jsma pgd deepfool cw --using-robust
# Out:
# -----Evaluating individual models (feature-squeezing-applied)-----
# 2025-12-11 22:42:57 - preprocessing.nslkdd_preprocessor - INFO - [+] Encoders loaded from encoders/nslkdd
# 2025-12-11 22:43:11 - __main__ - INFO -
# +-------------+---------------------+---------------------+---------------------+---------------------+---------------------+
# | Attack/File |         xgb         |         catb        |         gbm         |       bagging       |         dnn         |
# +-------------+---------------------+---------------------+---------------------+---------------------+---------------------+
# |   original  |   99.49% (asr:--)   |   99.37% (asr:--)   |   99.26% (asr:--)   |   99.29% (asr:--)   |   97.87% (asr:--)   |
# |      cw     | 80.55% (asr:19.04%) | 82.09% (asr:17.39%) | 85.41% (asr:13.98%) | 82.20% (asr:17.25%) | 82.82% (asr:15.39%) |
# |   deepfool  | 30.74% (asr:69.28%) | 24.19% (asr:75.86%) | 26.49% (asr:73.58%) | 19.88% (asr:80.17%) |  0.87% (asr:99.81%) |
# ...

# %% [markdown]
# ### Individual models: Full Defenses (APELID-ATH: adversarial robusting + feature squeezing)

# %%
# !echo "-----Evaluating individual models (APELID-ATH)-----"
# !cd ..; python cli/apelid/8_attack_evaluation/classifier_evaluate_adv.py -r nslkdd -m xgb catb gbm bagging dnn -a zoo hsja fgsm jsma pgd deepfool cw --using-robust --fs-enable --fs-config xgb:6 catb:8 gbm:8 bagging:8 dnn:2
# Out:
# -----Evaluating individual models (APELID-ATH)-----
# 2025-12-11 22:43:33 - preprocessing.nslkdd_preprocessor - INFO - [+] Encoders loaded from encoders/nslkdd
# 2025-12-11 22:43:47 - __main__ - INFO -
# +-------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# | Attack/File |        xgb         |        catb        |        gbm         |      bagging       |        dnn         |
# +-------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |   original  |  99.52% (asr:--)   |  99.48% (asr:--)   |  99.22% (asr:--)   |  99.32% (asr:--)   |  89.29% (asr:--)   |
# |      cw     | 94.50% (asr:5.06%) | 94.83% (asr:4.69%) | 95.13% (asr:4.15%) | 93.10% (asr:6.31%) | 89.26% (asr:0.06%) |
# |   deepfool  | 98.03% (asr:1.63%) | 97.96% (asr:1.70%) | 96.44% (asr:3.10%) | 95.15% (asr:4.43%) | 92.95% (asr:0.74%) |
# ...

# %% [markdown]
# ### Ensemble model (APELID): No defenses

# %%
# !echo "-----Evaluating APELID (no defense)-----"
# !cd ..; python cli/apelid/8_attack_evaluation/classifier_parallel_ens_eval.py -a zoo hsja fgsm jsma pgd deepfool cw -r nslkdd
# Out:
# -----Evaluating APELID (no defense)-----
# 2025-12-11 22:43:52 - __main__ - INFO - [+] Loading plain test data: data/nslkdd_test_random_sample_clean_merged.csv
# 2025-12-11 22:43:52 - preprocessing.nslkdd_preprocessor - INFO - [+] Encoders loaded from encoders/nslkdd
# 2025-12-11 22:43:52 - __main__ - INFO - [+] using_histgbm is OFF: disabled 'histgbm', using 'gbm' if present
# 2025-12-11 22:43:52 - __main__ - INFO - [+] Ensemble models: ['xgb', 'dnn', 'catb', 'bagging', 'gbm']
# 2025-12-11 22:44:04 - __main__ - INFO -
# +-------------+--------+--------+-----------+--------+--------+
# | Attack/File |  Acc   |   F1   | Precision | Recall |  ASR   |
# +-------------+--------+--------+-----------+--------+--------+
# |   original  | 99.46% | 99.46% |   99.46%  | 99.46% |   --   |
# |     zoo     | 75.73% | 75.73% |   75.73%  | 75.73% | 24.13% |
# |     hsja    | 38.15% | 38.15% |   38.15%  | 38.15% | 61.93% |
# |     fgsm    | 89.38% | 89.38% |   89.38%  | 89.38% | 10.14% |
# ...

# %% [markdown]
# ### Individual models: Ablation study

# %%
# !echo "-----Evaluating APELID (feature-squeezing-applied: APELID-FS)-----"
# !cd ..; python cli/apelid/8_attack_evaluation/classifier_parallel_ens_eval.py -a zoo hsja fgsm jsma pgd deepfool cw -r nslkdd --fs-enable --fs-config xgb:6 catb:8 gbm:8 bagging:8 dnn:2
# !echo "-----Evaluating APELID (adversarial-robusted-only: APELID-HT)-----"
# !cd ..; python cli/apelid/8_attack_evaluation/classifier_parallel_ens_eval.py -a zoo hsja fgsm jsma pgd deepfool cw -r nslkdd --using-robust
# !echo "-----Evaluating APELID (APELID-isolated-robust: APELID-IR)-----"
# !cd ..; python cli/apelid/8_attack_evaluation/classifier_parallel_ens_eval.py -a zoo hsja fgsm jsma pgd deepfool cw -r nslkdd --using-isolated-robust --fs-enable --fs-config xgb:6 catb:8 gbm:8 bagging:8 dnn:2
# Out:
# -----Evaluating APELID (feature-squeezing-applied: APELID-FS)-----
# 2025-12-11 22:44:09 - __main__ - INFO - [+] Loading plain test data: data/nslkdd_test_random_sample_clean_merged.csv
# 2025-12-11 22:44:10 - preprocessing.nslkdd_preprocessor - INFO - [+] Encoders loaded from encoders/nslkdd
# 2025-12-11 22:44:10 - __main__ - INFO - [+] using_histgbm is OFF: disabled 'histgbm', using 'gbm' if present
# 2025-12-11 22:44:10 - __main__ - INFO - [+] Ensemble models: ['xgb', 'dnn', 'catb', 'bagging', 'gbm']
# 2025-12-11 22:44:21 - __main__ - INFO -
# +-------------+--------+--------+-----------+--------+--------+
# | Attack/File |  Acc   |   F1   | Precision | Recall |  ASR   |
# +-------------+--------+--------+-----------+--------+--------+
# |   original  | 99.46% | 99.46% |   99.46%  | 99.46% |   --   |
# |     zoo     | 77.10% | 77.10% |   77.10%  | 77.10% | 22.74% |
# |     hsja    | 76.49% | 76.49% |   76.49%  | 76.49% | 23.24% |
# ...

# %% [markdown]
# ### Individual models: Full Defenses (APELID-ATH: adversarial robusting + feature squeezing)

# %%
# !echo "-----Evaluating APELID (APELID-ATH)-----"
# !cd ..; python cli/apelid/8_attack_evaluation/classifier_parallel_ens_eval.py -a zoo hsja fgsm jsma pgd deepfool cw -r nslkdd --using-robust --fs-enable --fs-config xgb:6 catb:8 gbm:8 bagging:8 dnn:2
# Out:
# -----Evaluating APELID (APELID-ATH)-----
# 2025-12-11 22:44:58 - __main__ - INFO - [+] Loading plain test data: data/nslkdd_test_random_sample_clean_merged.csv
# 2025-12-11 22:44:58 - preprocessing.nslkdd_preprocessor - INFO - [+] Encoders loaded from encoders/nslkdd
# 2025-12-11 22:44:59 - __main__ - INFO - [+] using_histgbm is OFF: disabled 'histgbm', using 'gbm' if present
# 2025-12-11 22:44:59 - __main__ - INFO - [+] Ensemble models: ['xgb', 'dnn', 'catb', 'bagging', 'gbm']
# 2025-12-11 22:45:10 - __main__ - INFO -
# +-------------+--------+--------+-----------+--------+-------+
# | Attack/File |  Acc   |   F1   | Precision | Recall |  ASR  |
# +-------------+--------+--------+-----------+--------+-------+
# |   original  | 99.46% | 99.46% |   99.46%  | 99.46% |   --  |
# |     zoo     | 99.40% | 99.40% |   99.40%  | 99.40% | 0.10% |
# |     hsja    | 99.37% | 99.37% |   99.37%  | 99.37% | 0.11% |
# |     fgsm    | 99.39% | 99.39% |   99.39%  | 99.39% | 0.24% |
# ...

# %% [markdown]
# # Dataset Summary

# %% [markdown]
# ## CSE-CIC-IDS2018

# %% [markdown]
# ### Balanced dataset

# %%
import pandas as pd

train_path = '../data/cic2018_merged_train_raw_processed.csv'
df_train = pd.read_csv(train_path)
# Label distribution
print(df_train['Label'].value_counts())
# Out:
# Label
# Bot                       14000
# DDoS attacks-LOIC-HTTP    14000
# SSH-Bruteforce            14000
# Brute Force -Web          14000
# DoS attacks-Hulk          14000
# DoS attacks-Slowloris     14000
# Brute Force -XSS          14000
# DDOS attack-HOIC          14000
# Benign                    14000
# DoS attacks-GoldenEye     14000
# Infilteration             14000
# SQL Injection             14000
# Name: count, dtype: int64

# %%
test_path = '../data/cic2018_test_random_sample_clean_merged.csv'
df_test = pd.read_csv(test_path)
# Label distribution
print(df_test['Label'].value_counts())
# Out:
# Label
# Benign                    6000
# DDoS attacks-LOIC-HTTP    6000
# DDOS attack-HOIC          6000
# DoS attacks-Hulk          6000
# Bot                       6000
# Infilteration             6000
# SSH-Bruteforce            6000
# DoS attacks-GoldenEye     6000
# DoS attacks-Slowloris     2914
# Brute Force -Web           122
# Brute Force -XSS            67
# SQL Injection               26
# Name: count, dtype: int64

# %% [markdown]
# ### Adversarial Training Dataset

# %% [markdown]
# Target:
# + ~ 7000 samples per label => `7000 samples * 12 labels / 7 attacks` => 12000 samples/attack
# + ~ 12000/12 = 1000 samples/label/attack

# %%
# !cd ..; python cli/apelid/7_generating_samples/label_distribution.py -r cic2018 -m xgb catb gbm bagging dnn -a zoo hsja fgsm jsma pgd deepfool cw
# Out:
# 2025-12-11 22:45:15 - __main__ - INFO - [+] Loading: resources/CIC-2018/adv_samples/robust/cic2018_xgb_robust_train_post.csv
# 2025-12-11 22:45:16 - __main__ - INFO - [Model=xgb] Label x Attack counts:
# +------------------------+-------+----------+-------+-------+-------+-------+-----+-------+
# |         label          |   cw  | deepfool |  fgsm |  hsja |  jsma |  pgd  | zoo | total |
# +------------------------+-------+----------+-------+-------+-------+-------+-----+-------+
# |         Benign         |  2000 |   1000   |  1000 |  1200 |  1265 |  1000 | 113 |  7578 |
# |          Bot           |   25  |   1000   |  1000 |  1200 |  1000 |  1000 |  0  |  5225 |
# |    Brute Force -Web    |  1664 |   1000   |  1000 |  1200 |  735  |  1000 | 211 |  6810 |
# |    Brute Force -XSS    |  1000 |   1000   |  1000 |  1200 |  1000 |  1000 |  0  |  6200 |
# |    DDOS attack-HOIC    |  1000 |   1000   |  1000 |  1200 |  1000 |  1000 |  0  |  6200 |
# ...

# %% [markdown]
# ## NSLKDD

# %% [markdown]
# ### Balanced dataset

# %%
train_path = '../data/nslkdd_merged_train_raw_processed.csv'
df_train = pd.read_csv(train_path)
# shape
print(df_train.shape)
# Label distribution
print(df_train['Label'].value_counts())

test_path = '../data/nslkdd_test_random_sample_clean_merged.csv'
df_test = pd.read_csv(test_path)
# Label distribution
print(df_test['Label'].value_counts())
# Out:
# (70000, 43)
# Label
# R2L       14000
# Probe     14000
# Benign    14000
# DoS       14000
# U2R       14000
# Name: count, dtype: int64
# Label
# Benign    6000
# DoS       6000
# Probe     4181
# R2L       1122
# U2R         33
# Name: count, dtype: int64

# %% [markdown]
# ### Adversarial Training Dataset

# %% [markdown]
# Target:
# + ~ 7000 samples per label => `7000 samples * 5 labels / 7 attacks` => 5000 samples/attack
# + ~ 5000/5 = 1000 samples/label/attack

# %%
# !cd ..; python cli/apelid/7_generating_samples/label_distribution.py -r nslkdd -m xgb catb gbm bagging dnn -a zoo hsja fgsm jsma pgd deepfool cw
# Out:
# 2025-12-11 22:45:21 - __main__ - INFO - [+] Loading: resources/NSLKDD/adv_samples/robust/nslkdd_xgb_robust_train_post.csv
# 2025-12-11 22:45:21 - __main__ - INFO - [Model=xgb] Label x Attack counts:
# +--------+------+----------+------+------+------+------+------+-------+
# | label  |  cw  | deepfool | fgsm | hsja | jsma | pgd  | zoo  | total |
# +--------+------+----------+------+------+------+------+------+-------+
# | Benign | 2000 |   1000   | 1000 | 1999 | 246  | 1000 | 2000 |  9245 |
# |  DoS   | 587  |   1000   | 1000 | 1000 |  6   | 1000 | 1577 |  6170 |
# | Probe  | 671  |   1000   | 1000 | 1000 | 898  | 1000 | 734  |  6303 |
# |  R2L   | 1708 |   1000   | 1000 | 1000 | 2000 | 1000 | 630  |  8338 |
# |  U2R   |  34  |   1000   | 1000 |  1   | 1850 | 1000 |  59  |  4944 |
# |  all   | 5000 |   5000   | 5000 | 5000 | 5000 | 5000 | 5000 | 35000 |
# +--------+------+----------+------+------+------+------+------+-------+
# ...
